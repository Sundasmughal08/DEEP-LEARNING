# %%
# 1. IMPORT LIBRARIES



import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import pandas as pd

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator #data augmentation

# %%
imgage_size=(150,150)
batch_size=32

# %%
train_datagen=ImageDataGenerator(rescale=1/255,
                                 shear_range=0.2, #check more option
                                 
                                 )

test_datagen=ImageDataGenerator(rescale=1/255,
                                 shear_range=0.2, #check more option
                                 )

# %%
training_set=train_datagen.flow_from_directory('Datasets/dataset/training_set',
                                               target_size=imgage_size,
                                               batch_size=batch_size,
                                               class_mode='binary')


test_set=train_datagen.flow_from_directory('Datasets/dataset/test_set',
                                               target_size=imgage_size,
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 training_set=train_datagen.flow_from_directory('Datasets/dataset/training_set',
#       2                                                target_size=imgage_size,
#       3                                                batch_size=batch_size,
#       4                                                class_mode='binary')
#       7 test_set=train_datagen.flow_from_directory('Datasets/dataset/test_set',
#       8                                                target_size=imgage_size,
#       9                                                batch_size=batch_size,
#      10                                                class_mode='binary')
#
# ...

# %%
model=keras.Sequential(
    [
        
        keras.layers.Conv2D(32,(3,3), activation='relu',input_shape=(150,150,3)),     
     
        keras.layers.MaxPooling2D((3,3)),     
        keras.layers.Conv2D(32,(3,3), activation='relu'),     
        keras.layers.MaxPooling2D((3,3)),     
        keras.layers.Conv2D(32,(3,3), activation='relu'),     
        keras.layers.Flatten(),     
        keras.layers.Dense(512, activation='relu',),     
        keras.layers.Dense(1, activation='sigmoid'),     
     
     ]
)
# Out:
# c:\Users\Laptop Links\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',metrics=['accuracy']


)


model.fit(training_set,epochs=10)
# Out:
# Epoch 1/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 70s 513ms/step - accuracy: 0.8035 - loss: 0.4501
# Epoch 2/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 73s 562ms/step - accuracy: 0.8216 - loss: 0.4106
# Epoch 3/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 69s 533ms/step - accuracy: 0.8352 - loss: 0.3727
# Epoch 4/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 70s 537ms/step - accuracy: 0.8521 - loss: 0.3402
# Epoch 5/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 88s 586ms/step - accuracy: 0.8697 - loss: 0.2996
# Epoch 6/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 73s 516ms/step - accuracy: 0.8960 - loss: 0.2482
# Epoch 7/10
# 115/129 ━━━━━━━━━━━━━━━━━━━━ 8s 579ms/step - accuracy: 0.9287 - loss: 0.1944

# %%
test_loss,test_acc= model.evaluate(training_set,test_set)
print('test loss : ',test_loss)

print('test accuracy : ',test_acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 test_loss,test_acc= model.evaluate(training_set,test_set)
#       2 print('test loss : ',test_loss)
#       4 print('test accuracy : ',test_acc)
#
# NameError: name 'model' is not defined
